# %% [markdown]
# ## Sublime Limes' Line Graphs
#
# In this project, you will be acting as a data analyst for an online lime retailer called Sublime Limes. People all over the world can use this product to get the freshest, best-quality limes delivered to their door. One of the product managers at Sublime Limes would like to gain insight into the customers and their sales habits. Using Matplotlib, you’ll create some different line graphs (or maybe, lime graphs) to communicate this information effectively.

# %% [markdown]
# ### Complete all the tasks below!
# ---

# %% [markdown]
# **1: We have provided some data in different lists in script.py. Look through these lists and try to understand what each one represents by running them.**

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]

visits_per_month = [9695, 7909, 10831, 12942, 12495, 16794, 14161, 12762, 12777, 12439, 10309, 8724]

# numbers of limes of different species sold each month
key_limes_per_month = [92.0, 109.0, 124.0, 70.0, 101.0, 79.0, 106.0, 101.0, 103.0, 90.0, 102.0, 106.0]
persian_limes_per_month = [67.0, 51.0, 57.0, 54.0, 83.0, 90.0, 52.0, 63.0, 51.0, 44.0, 64.0, 78.0]
blood_limes_per_month = [75.0, 75.0, 76.0, 71.0, 74.0, 77.0, 69.0, 80.0, 63.0, 69.0, 73.0, 82.0]

# %% [markdown]
# **2: Create a figure of width 12 and height 8.**

# %%
# code for task2
plt.figure(figsize=(12, 8))

# %% [markdown]
# **3: We are going to make two charts in one figure, laid out side-by-side. In other words, the figure will have one row and two columns, like the image below.**
#
# **Write the command to create the left subplot (the one that would correspond to the plot with a star in our example figure). Save this subplot in a variable called ```ax1```.**
#
# <img src="https://s3.amazonaws.com/codecademy-content/courses/matplotlib/project_i/side_by_side_subplot.png" style="width:350px;float:left;">

# %%
plt.figure(figsize=(12, 8))

# code for task3
ax1 = plt.subplot(1, 2, 1)

plt.show()

# %% [markdown]
# **4: Write the command to create the right subplot (the one that would correspond to the plot with a square in our example figure).**
#
# **Save this subplot in a variable called ```ax2```.**

# %%
plt.figure(figsize=(12, 8))

ax1 = plt.subplot(1, 2, 1)

# code for task4
ax2 = plt.subplot(1, 2, 2)

plt.show()

# %% [raw]
# **5: In the left subplot, we are going to plot the total page visits over the past year as a line.**
#
# **First, let’s create the list of x-values, which is range(len(months)). Store this in a variable called x_values.**
#
# **Make sure this happens after the line where you created ax1, but before the line where you’ve created ax2, so that the plot goes in the subplot on the left.**

# %%
plt.figure(figsize=(12, 8))

ax1 = plt.subplot(1, 2, 1)

# code for task5
x_values = range(len(months))

ax2 = plt.subplot(1, 2, 2)

plt.show()

# %% [markdown]
# **6: Plot the total page visits against these ```x_values``` as a line.**

# %%
plt.figure(figsize=(12, 8))

ax1 = plt.subplot(1, 2, 1)
x_values = range(len(months))

# code for task6
plt.plot(x_values, visits_per_month)

ax2 = plt.subplot(1, 2, 2)

plt.show()

# %% [markdown]
# **7: Give the line markers that will help show each month as a distinct value.**

# %%
plt.figure(figsize=(12, 8))

ax1 = plt.subplot(1, 2, 1)
x_values = range(len(months))

# code for task7(modify the one from task6)
plt.plot(x_values, visits_per_month, marker='s')

ax2 = plt.subplot(1, 2, 2)

plt.show()

# %% [markdown]
# **8: Label the x-axis and y-axis with descriptive titles of what they measure.**

# %%
plt.figure(figsize=(12, 8))

ax1 = plt.subplot(1, 2, 1)
x_values = range(len(months))
plt.plot(x_values, visits_per_month, marker='s')

# code for task 8
plt.xlabel('Months')
plt.ylabel('Visits')

ax2 = plt.subplot(1, 2, 2)

plt.show()

# %% [markdown]
# **9: Set the x-axis ticks to be the ```x_values```.**

# %%
plt.figure(figsize=(12, 8))

ax1 = plt.subplot(1, 2, 1)
x_values = range(len(months))
plt.plot(x_values, visits_per_month, marker='s')
plt.xlabel('Months')
plt.ylabel('Visits')

# code for task9
ax1.set_xticks(x_values)
ax1.set_xticklabels(months)

ax2 = plt.subplot(1, 2, 2)

plt.show()

# %% [markdown]
# **10: In the subplot on the right, we are going to plot three lines on the same set of axes. The x-values for all three lines will correspond to the months, so we can use the list of x_values we used for the last plot.**
#
# **On one plot, create the three lines:**
#
# - number of key limes sold vs ```x_values```
# - number of Persian limes sold vs ```x_values```
# - number of blood limes sold vs ```x_values```
#
# **Make sure this happens after the line where you created ax2, so that it goes in the subplot on the right.**

# %%
plt.figure(figsize=(12, 8))

ax1 = plt.subplot(1, 2, 1)
x_values = range(len(months))
plt.plot(x_values, visits_per_month, marker='s')
plt.xlabel('Months')
plt.ylabel('Visits')
ax1.set_xticks(x_values)
ax1.set_xticklabels(months)

ax2 = plt.subplot(1, 2, 2)

# code for task10
plt.plot(x_values, key_limes_per_month)
plt.plot(x_values, persian_limes_per_month)
plt.plot(x_values, blood_limes_per_month)

plt.show()

# %% [markdown]
# **11: Give each line a specific color of your choosing.　Also add distinctive markers to each line as well (you can use a same marker for all the lines.)**

# %%
plt.figure(figsize=(12, 8))

ax1 = plt.subplot(1, 2, 1)
x_values = range(len(months))
plt.plot(x_values, visits_per_month, marker='s')
plt.xlabel('Months')
plt.ylabel('Visits')
ax1.set_xticks(x_values)
ax1.set_xticklabels(months)

ax2 = plt.subplot(1, 2, 2)

# code for task11(modify the one from task10)
plt.plot(x_values, key_limes_per_month, color='red', marker='o')
plt.plot(x_values, persian_limes_per_month, color='blue', marker='o')
plt.plot(x_values, blood_limes_per_month, color='green', marker='o')

plt.show()

# %% [markdown]
# **12: Label the x-axis and y-axis with descriptive titles of what they measure.**

# %%
plt.figure(figsize=(12, 8))

ax1 = plt.subplot(1, 2, 1)
x_values = range(len(months))
plt.plot(x_values, visits_per_month, marker='s')
plt.xlabel('Months')
plt.ylabel('Visits')
ax1.set_xticks(x_values)
ax1.set_xticklabels(months)

ax2 = plt.subplot(1, 2, 2)
plt.plot(x_values, key_limes_per_month, color='red', marker='o')
plt.plot(x_values, persian_limes_per_month, color='blue', marker='o')
plt.plot(x_values, blood_limes_per_month, color='green', marker='o')

# code for task12
plt.xlabel('Months')
plt.ylabel('Numbers of limes sold')

plt.show()

# %% [markdown]
# **13: Add a legend to differentiate the lines, labeling each lime species.**

# %%
plt.figure(figsize=(12, 8))

ax1 = plt.subplot(1, 2, 1)
x_values = range(len(months))
plt.plot(x_values, visits_per_month, marker='s')
plt.xlabel('Months')
plt.ylabel('Visits')
ax1.set_xticks(x_values)
ax1.set_xticklabels(months)

ax2 = plt.subplot(1, 2, 2)
plt.plot(x_values, key_limes_per_month, color='red', marker='o')
plt.plot(x_values, persian_limes_per_month, color='blue', marker='o')
plt.plot(x_values, blood_limes_per_month, color='green', marker='o')
plt.xlabel('Months')
plt.ylabel('Numbers of limes sold')

# code for task13
plt.legend(['Key Limes', 'Persian Limes', 'Blood Limes'])

plt.show()

# %% [markdown]
# **14: Set the x-axis ticks to be the ```x_values```, and the tick labels to be the ```months``` list.**

# %%
plt.figure(figsize=(12, 8))

ax1 = plt.subplot(1, 2, 1)
x_values = range(len(months))
plt.plot(x_values, visits_per_month, marker='s')
plt.xlabel('Months')
plt.ylabel('Visits')
ax1.set_xticks(x_values)
ax1.set_xticklabels(months)

ax2 = plt.subplot(1, 2, 2)
plt.plot(x_values, key_limes_per_month, color='red', marker='o')
plt.plot(x_values, persian_limes_per_month, color='blue', marker='o')
plt.plot(x_values, blood_limes_per_month, color='green', marker='o')
plt.xlabel('Months')
plt.ylabel('Numbers of limes sold')
plt.legend(['Key Limes', 'Persian Limes', 'Blood Limes'])

# code for task14
ax2.set_xticks(x_values)
ax2.set_xticklabels(months)

plt.show()

# %% [markdown]
# **15: Add a title to each of the two plots you’ve created, and adjust the margins to make the text you’ve added look better.**

# %%
plt.figure(figsize=(12, 8))

ax1 = plt.subplot(1, 2, 1)
x_values = range(len(months))
plt.plot(x_values, visits_per_month, marker='s')
plt.xlabel('Months')
plt.ylabel('Visits')
ax1.set_xticks(x_values)
ax1.set_xticklabels(months)

# code for task15(title for the subplot left)
plt.title('Total Visits per Month')

ax2 = plt.subplot(1, 2, 2)
plt.plot(x_values, key_limes_per_month, color='red', marker='o')
plt.plot(x_values, persian_limes_per_month, color='blue', marker='o')
plt.plot(x_values, blood_limes_per_month, color='green', marker='o')
plt.xlabel('Months')
plt.ylabel('Numbers of limes sold')
plt.legend(['Key Limes', 'Persian Limes', 'Blood Limes'])
ax2.set_xticks(x_values)
ax2.set_xticklabels(months)

# code for task15(title for the subplot right, and subplots adjustment)
plt.title('Number of different limes sold each month')
plt.subplots_adjust(wspace=0.3)

plt.show()

# %% [markdown]
# **16: Now, save your figure as a png with a descriptive file name.**

# %%
plt.figure(figsize=(12, 8))

ax1 = plt.subplot(1, 2, 1)
x_values = range(len(months))
plt.plot(x_values, visits_per_month, marker='s')
plt.xlabel('Months')
plt.ylabel('Visits')
ax1.set_xticks(x_values)
ax1.set_xticklabels(months)
plt.title('Total Visits per Month')

ax2 = plt.subplot(1, 2, 2)
plt.plot(x_values, key_limes_per_month, color='red', marker='o')
plt.plot(x_values, persian_limes_per_month, color='blue', marker='o')
plt.plot(x_values, blood_limes_per_month, color='green', marker='o')
plt.xlabel('Months')
plt.ylabel('Numbers of limes sold')
plt.legend(['Key Limes', 'Persian Limes', 'Blood Limes'])
ax2.set_xticks(x_values)
ax2.set_xticklabels(months)
plt.title('Number of different limes sold each month')

plt.subplots_adjust(wspace=0.3)

# code for task16
plt.savefig('number_of_visitors_and_limes.png')

plt.show()
